# %%
import pandas as pd

df = pd.read_excel('Superstore Dataset.xlsx')

# %%
df
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                    1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1                    2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2                    3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3                   13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4                   14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...                ...             ...        ...        ...             ...
# 5894              9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895              9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896              9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897              9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898              9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit'],
#       dtype='object')

# %%
df.drop(['Row ID+O6G3A1:R6'], axis=1)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1     CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2     CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 3     CA-2020-114412 2020-04-15 2020-04-20  Standard Class    AA-10480
# 4     CA-2019-161389 2019-12-05 2019-12-10  Standard Class    IM-15070
# ...              ...        ...        ...             ...         ...
# 5894  CA-2020-163629 2020-11-17 2020-11-21  Standard Class    RA-19885
# 5895  CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 5896  CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 5897  CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 5898  CA-2020-119914 2020-05-04 2020-05-09    Second Class    CC-12220
#
#         Customer Name    Segment        Country         City           State  \
# ...

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)
